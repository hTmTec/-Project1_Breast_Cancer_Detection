# %%
import numpy as np   
import pandas as pd 
import matplotlib.pyplot as plt

# %%
cols = ["fLength", "fWidth", "fSize", "fConc", "fConc1", "fM3Long", "fM3Trans", "fAlpha", "fDist", "Class"]
df = pd.read_csv('magic04.data', names=cols)
df.head()
# Out:
#            fLength  fWidth   fSize   fConc    fConc1  fM3Long  fM3Trans  \
# 28.7967    16.0021  2.6449  0.3918  0.1982   27.7004  22.0110   -8.2027
# 31.6036    11.7235  2.5185  0.5303  0.3773   26.2722  23.8238   -9.9574
# 162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580  -45.2160
# 23.8172     9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633   -7.1513
# 75.1362    30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525   21.8393
#
#            fAlpha     fDist Class
# 28.7967   40.0920   81.8828     g
# 31.6036    6.3609  205.2610     g
# 162.0520  76.9600  256.7880     g
# 23.8172   10.4490  116.7370     g
# 75.1362    4.6480  356.4620     g

# %%
df["Class"].unique()
# Out:
# array(['g', 'h'], dtype=object)

# %%
df["Class"]= (df["Class"] == "g").astype(int)

# %%
pd.read_csv('magic04.data', names=cols)
# Out:
#            fLength  fWidth   fSize   fConc    fConc1   fM3Long  fM3Trans  \
# 28.7967    16.0021  2.6449  0.3918  0.1982   27.7004   22.0110   -8.2027
# 31.6036    11.7235  2.5185  0.5303  0.3773   26.2722   23.8238   -9.9574
# 162.0520  136.0310  4.0612  0.0374  0.0187  116.7410  -64.8580  -45.2160
# 23.8172     9.5728  2.3385  0.6147  0.3922   27.2107   -6.4633   -7.1513
# 75.1362    30.9205  3.1611  0.3168  0.1832   -5.5277   28.5525   21.8393
# ...            ...     ...     ...     ...       ...       ...       ...
# 21.3846    10.9170  2.6161  0.5857  0.3934   15.2618   11.5245    2.8766
# 28.9452     6.7020  2.2672  0.5351  0.2784   37.0816   13.1853   -2.9632
# 75.4455    47.5305  3.4483  0.1417  0.0549   -9.3561   41.0562   -9.4662
# 120.5135   76.9018  3.9939  0.0944  0.0683    5.8043  -93.5224  -63.8389
# 187.1814   53.0014  3.2093  0.2876  0.1539 -167.3125 -168.4558   31.4755
#
#            fAlpha     fDist Class
# 28.7967   40.0920   81.8828     g
# 31.6036    6.3609  205.2610     g
# 162.0520  76.9600  256.7880     g
# 23.8172   10.4490  116.7370     g
# 75.1362    4.6480  356.4620     g
# ...           ...       ...   ...
# 21.3846    2.4229  106.8258     h
# 28.9452   86.7975  247.4560     h
# 75.4455   30.2987  256.5166     h
# 120.5135  84.6874  408.3166     h
# 187.1814  52.7310  272.3174     h
#
# [19020 rows x 10 columns]

# %%
df.head()
# Out:
#            fLength  fWidth   fSize   fConc    fConc1  fM3Long  fM3Trans  \
# 28.7967    16.0021  2.6449  0.3918  0.1982   27.7004  22.0110   -8.2027
# 31.6036    11.7235  2.5185  0.5303  0.3773   26.2722  23.8238   -9.9574
# 162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580  -45.2160
# 23.8172     9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633   -7.1513
# 75.1362    30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525   21.8393
#
#            fAlpha     fDist  Class
# 28.7967   40.0920   81.8828      1
# 31.6036    6.3609  205.2610      1
# 162.0520  76.9600  256.7880      1
# 23.8172   10.4490  116.7370      1
# 75.1362    4.6480  356.4620      1

# %%
for label in cols [:-1]:    
  plt.hist(df[df["Class"]==1][label], color='blue', label= 'gamma', alpha=0.7, density=True)
  plt.hist(df[df["Class"]==0][label], color='red', label= 'hadron', alpha=0.7, density=True)
  plt.title(label)
  plt.ylabel("probability")
  plt.xlabel (label)
  plt.legend()
  plt.show()

# %% [markdown]
# #Train, Validation, Test Datasets

# %%
train, valid, test = np.split (df.sample(frac=1),[int(0.6*len(df)), int (0.8*len(df))])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Float64Engine._maybe_get_bool_indexer()
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._unpack_bool_indexer()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-79cbed98324c> in <module>
# ----> 1 train, valid, test = np.split (df.sample(frac=1),[int(0.6*len(df)), int (0.8*len(df))])
#
# <__array_function__ internals> in split(*args, **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/numpy/lib/shape_base.py in split(ary, indices_or_sections, axis)
#     872             raise ValueError(
#     873                 'array split does not result in an equal division') from None
# --> 874     return array_split(ary, indices_or_sections, axis)
#     875
#     876
#
# <__array_function__ internals> in array_split(*args, **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/numpy/lib/shape_base.py in array_split(ary, indices_or_sections, axis)
#     788         st = div_points[i]
#     789         end = div_points[i + 1]
# --> 790         sub_arys.append(_nx.swapaxes(sary[st:end], axis, 0))
#     791
#     792     return sub_arys
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3428
#    3429         # Do we have a slicer (on rows)?
# -> 3430         indexer = convert_to_index_sliceable(self, key)
#    3431         if indexer is not None:
#    3432             if isinstance(indexer, np.ndarray):
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in convert_to_index_sliceable(obj, key)
#    2327     idx = obj.index
#    2328     if isinstance(key, slice):
# -> 2329         return idx._convert_slice_indexer(key, kind="getitem")
#    2330
#    2331     elif isinstance(key, str):
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/numeric.py in _convert_slice_indexer(self, key, kind)
#     240             # We always treat __getitem__ slicing as label-based
#     241             # translate to locations
# --> 242             return self.slice_indexer(key.start, key.stop, key.step, kind=kind)
#     243
#     244         return super()._convert_slice_indexer(key, kind=kind)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in slice_indexer(self, start, end, step, kind)
#    5683         slice(1, 3, None)
#    5684         """
# -> 5685         start_slice, end_slice = self.slice_locs(start, end, step=step)
#    5686
#    5687         # return a slice
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in slice_locs(self, start, end, step, kind)
#    5885         start_slice = None
#    5886         if start is not None:
# -> 5887             start_slice = self.get_slice_bound(start, "left")
#    5888         if start_slice is None:
#    5889             start_slice = 0
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_slice_bound(self, label, side, kind)
#    5805             except ValueError:
#    5806                 # raise the original KeyError
# -> 5807                 raise err
#    5808
#    5809         if isinstance(slc, np.ndarray):
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_slice_bound(self, label, side, kind)
#    5799         # we need to look up the label
#    5800         try:
# -> 5801             slc = self.get_loc(label)
#    5802         except KeyError as err:
#    5803             try:
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 0
